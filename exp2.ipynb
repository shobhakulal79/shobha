# %% [markdown]
# <a href="https://colab.research.google.com/github/shobhakulal79/shobha/blob/main/exp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data={
    'First':['Aryan','Rohan','Riya','Yash','Siddhant'],
    'Lastname':['Singh','Agarwal','Shah','Bhatia','Khanna'],
    'Type':['Full_time employee','Intern','Full_time employee','Part_time employee','Full_time employee'],
    'Department':['Administration','Technical','Administration','Technical','Technical'],
    'yoe':[2,3,5,7,6],
    'Salary':[20000,5000,10000,20000,4000]
}
df=pd.DataFrame(data)
print(df)
table=pd.pivot_table(df, index=['Type','Department'], values='Salary', aggfunc=['mean'])
print(table)
table1=pd.pivot_table(df,index=['Type','Department'],values='Salary',aggfunc=['sum','mean'])
print(table1)
table2=pd.pivot_table(df,index=['Type',],values='Salary',aggfunc=['count'])
print(table2)
table3=pd.pivot_table(df,index=['Type',],values='Salary',aggfunc=['std'])
print(table3)
# Out:
#       First Lastname                Type      Department  yoe  Salary
# 0     Aryan    Singh  Full_time employee  Administration    2   20000
# 1     Rohan  Agarwal              Intern       Technical    3    5000
# 2      Riya     Shah  Full_time employee  Administration    5   10000
# 3      Yash   Bhatia  Part_time employee       Technical    7   20000
# 4  Siddhant   Khanna  Full_time employee       Technical    6    4000
#                                       mean
#                                     Salary
# Type               Department
# Full_time employee Administration  15000.0
#                    Technical        4000.0
# Intern             Technical        5000.0
# Part_time employee Technical       20000.0
#                                      sum     mean
#                                   Salary   Salary
# Type               Department
# Full_time employee Administration  30000  15000.0
#                    Technical        4000   4000.0
# Intern             Technical        5000   5000.0
# Part_time employee Technical       20000  20000.0
#                     count
#                    Salary
# Type
# Full_time employee      3
# Intern                  1
# Part_time employee      1
#                             std
#                          Salary
# Type
# Full_time employee  8082.903769
