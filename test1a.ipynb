# %% [markdown]
# <a href="https://colab.research.google.com/github/shobhakulal79/shobha/blob/main/test1a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
Cars_df=pd.read_csv('/content/Cars93 (12).csv')
print(Cars_df)
fig,ax=plt.subplots(2,3)
fig.set_figwidth(10)
fig.set_figheight(7)
fig.suptitle('multiple box plots',fontsize=16)
ax[0][0].boxplot(Cars_df["Price"][Cars_df["Type"]=="Compact"])
ax[0][0].sup_title=('Compact')
ax[0][1].boxplot(Cars_df["Price"][Cars_df["Type"]=="Large"])
ax[0][1].sup_title=('Large')
ax[0][2].boxplot(Cars_df["Price"][Cars_df["Type"]=="Midsize"])
ax[0][2].sup_title=('Midsize')
ax[1][0].boxplot(Cars_df["Price"][Cars_df["Type"]=="Small"])
ax[1][0].sup_title=('Small')
ax[1][1].boxplot(Cars_df["Price"][Cars_df["Type"]=="Sporty"])
ax[1][1].sup_title=('Sporty')
ax[1][2].boxplot(Cars_df["Price"][Cars_df["Type"]=="Van"])
ax[1][2].sup_title=('Van')
plt.hist(Cars_df["MPG.city"],color=('black'))
plt.xlabel("MPG.city")
plt.title("frequency distribution of MPG.city",color=('black'))
plt.show()

plt.plot(Cars_df["Enginsize"],["Horsepower"])
plt.xlabel('Engine size')
plt.ylabel('Horsepower')
plt.title("line chart to observe the variation in Enginesize against Horsepower")
plt.show()
# Out:
#     Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0            1        Acura  Integra    Small       12.9   15.9       18.8
# 1            2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2            3         Audi       90  Compact       25.9   29.1       32.3
# 3            4         Audi      100  Midsize       30.8   37.7       44.6
# 4            5          BMW     535i  Midsize       23.7   30.0       36.2
# ..         ...          ...      ...      ...        ...    ...        ...
# 88          89   Volkswagen  Eurovan      Van       16.6   19.7       22.7
# 89          90   Volkswagen   Passat  Compact       17.6   20.0       22.4
# 90          91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7
# 91          92        Volvo      240  Compact       21.8   22.7       23.5
# 92          93        Volvo      850  Midsize       24.8   26.7       28.5
#
# ...
